# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib.font_manager as fm
font_name = fm.FontProperties(fname='/Users/hoon/Library/Fonts/NanumSquareRegular.ttf').get_name()
plt.rc("font", family=font_name)

import matplotlib as mpl
mpl.rcParams["axes.unicode_minus"] = False

# %% [markdown]
# # XML(Extension Markup Language)
# https://docs.python.org/3/library/xml.etree.elementtree.html?highlight=xml#xml.etree.ElementTree.XML
#
# 1.특징
#
#   1) 메타 언어 : GML -> SGML -> XML
#   2) 데이터를 위한 언어
#   3) 데이터베이스 용도
#   4) 데이터 표준화 : 이 기종 시스템간의 정보교환, 웹서비스, 유비쿼터스, 사물인터넷 기타등등...
#
#   문법(물리적인 구성요소)
#   - 1) XML(.xml)
#   - 2) DTD(.dtd) : XML 작성을 위한 설계문서
#   - 3) XML Schema(.xsd) : XML 작성을 위한 설계문서
#   - 4) XSL(.xsl, xslt) : XML문서에 스타일을 입혀주는 언어
#
#   결과 문서의 종류
#   - 1) Well-Formed XML Document(잘 짜여진 문서)
#   - 2) Valid XML Document(유효한 문서)
#
# ## Element 문법
#
# 작성 규칙
# a) 모든 XML문서는 반드시 단 하나의 루트 엘리먼트를 가진다.
# b) 루트 엘리먼트는 여러 개의 자식 엘리먼트를 가질 수 있고 또 그 자식도 자신의 자식을 가질 수 있다.
# c) 시작태그와 끝태그는 반드시 짝을 이루어야 한다.
# d) "<"는 값으로 사용 불가. ">"는 사용할 수 있으나 가급적 사용 금지
# e) "<"와 ">" 다음에 공백문자가 올 수 없으며 반드시 시작태그와 끝태그의 이름이 같아야 한다.
#
# 종류
# a) 내용을 가지는 엘리먼트
# b) 내용이 없는 엘리먼트
#
# 내용에 대한 종류
# a) 문자 데이터
# b) 자식 엘리먼트
# c) 엔티티 또는 문자 참조
# d) CDATA Section
# e) 프로세싱 지시자
# f) 주석 :
# g) 공백 문자열
#
# DTD
#
# 종류 내부 DTD 외부 DTD
#
# 구성 요소 엘리먼트 선언 속성(attribute) 선언 Entity 선언 Notation 선언 프로세싱 지시자 파라미터 엔티티 참조 주석 공백 conditional section
#
# 문서 유형 선언 <!DOCTYPE 루트엘리먼트명 SYSTEM 또는 PUBLIC "식별자">
#
#   DOCTYPE은 반드시 대문자
#   SYSTEM은 특정 단체나 업체내부에서 사용되는 경우
#   PUBLIC은 공개
#   식별자는 다운로드 받을 수 있는 경로
#   PUBLIC일 경우 추가된 식별자
#   +-//DTD를 개발 및 유지보수 업체명//DTD명 및 버전번호//사용된 언어
# 엘리먼트 선언 <!ELEMENT 엘리먼트명 컨텐트 유형>
#
#   컨텐트 유형
#       #PCDATA : 내용으로 문자데이터만 갖는 엘리먼트
#       자식 엘리먼트
#           , : 작성 순서
#           | : 선택
#           ? : 생략하거나 한번만 작성
#           + : 한번 이상
#           * : 생략하거나 여러번 작성
#           기호 없음 : 단 한번만 작성
#       EMPTY
#       MIXED : 문자데이터 또는 자식엘리먼트를 혼합형태
#       ANY
# ATTRIBUTE 선언 <!ATTLIST 엘리먼트명 속성명 속성유형 디폴트선언>
#
#   속성 유형
#       CDATA :  문자 데이터
#       ENUMERATION : dtd에 나열된 값 중 하나가 와야 함
#       ID : 유일한 값을 지정
#       IDREF/IDREFS : ID값을 참조
#       NMTOKEN/NMTOKENS : 이름 작성 규칙을 준수하는 데이터만 사용
#       NOTATION : dtd에 명시적으로 선언된 notation만 사용가능
#       ENTITY : dtd에 명시적으로 선언된 entity만 사용 가능
# validation check https://www.xmlvalidation.com/
#
# 네임 스페이스
#
# CML
#  <?xml version=1.0>
#  <정보>
#      <고유번호>111111-1111111</고유번호>
#      <이름>홍길동</이름>
#      ...
#  </정보>
#
# PML
#  <?xml version=1.0>
#  <정보>
#      <고유번호>LC100</고유번호>
#      <이름>캠코더</이름>
#      ...
#  </정보>
#
# OML
#  <?xml version=1.0>
#  <주문정보 xmlns:고객="http://www.a.com/2017/Custom"
#      xmlns:상품="http://www.a.com/2017/Product"
#      xmlns="http://www.a.com/2017/Order">
#      <주문번호>1</주문번호>
#      <주문수량>10</주문수량>
#      <결제>
#          <방법>현금</방법>
#          <금액>10000000</금액>
#      </결제>
#
#      <고객:고유번호>111111-1111111</고객:고유번호>
#      <고객:이름>홍길동</고객:이름>
#
#      <상품:고유번호>LC100</상품:고유번호>
#      <상품:이름>캠코더</상품:이름>
#      ...
#  </주문정보>

# %%
import xml.etree.ElementTree as elemTree

###### XML을 사용하는 방법
# 1. XML파일로 존재하는 경우 : parse()
# 2. XML 문자열로 존재하는 경우 : fromstring()

# %%
tree1 = elemTree.parse("data/users.xml")
tree1

# %%
xmlstr = """<?xml version="1.0" encoding="utf-8" ?>
<users>
    <user grade="gold">
            <name>Kim Cheol Soo</name>
            <age>25</age>
            <birthday>19940215</birthday>
        </user>
    <user grade="diamond">
            <name>Kim Yoo Mee</name>
            <age>21</age>
            <birthday>19980417</birthday>
        </user>
</users>
"""

tree2 = elemTree.fromstring(xmlstr)
tree2
# Out:
# <Element 'users' at 0x7f7dd8022630>

# %% [markdown]
# ## 2. XML 데이터 다루기

# %% [markdown]
# #### (1) 태그명 검색

# %%
tree1.find("user")
tree1.find("user[1]")
data = tree1.find("user[2]")

# %%
print(data)
print(type(data))
dir(data)
print(data.tag)
print(data.attrib)
print(data.get("grade"))


print("="*50)


username = data.find("name")
#data는 user[2], 즉 다이아 등급의 김유미 고객 데이터가 저장되어있는 객체다.
print(username.tag)
print(username.attrib)
print(username.text)
# Out:
# <Element 'user' at 0x7f7dd8022cc0>
# <class 'xml.etree.ElementTree.Element'>
# user
# {'grade': 'diamond'}
# diamond
# ...
# name
# {}
# Kim Yoo Mee

# %% [markdown]
# #### (2) 태그 조건으로 검색

# %%
data = tree1.find('./user[@grade]')
# data = tree1.find('./user[@grade][1]')
# 순서대로 접근하는 방식이기 때문에 인덱스 지정해주지 않으면 첫번째 값을 불러온다.
# user를 따로 지정해주지 않으면 첫번째 유저, 즉 등급이 골드인 유저를 가져온다.

print(data.attrib)
print(data.keys())
print(data.items())
print(data.attrib['grade']) #print(data.get('grade'))
# Out:
# {'grade': 'gold'}
# ['grade']
# [('grade', 'gold')]
# gold

# %% [markdown]
# #### (3) 여러 개의 태그를 한꺼번에 가져오기

# %%
users = tree1.findall("./user")
users
# [<Element 'user' at 0x7f7e188f7540>, <Element 'user' at 0x7f7dd8022cc0>]
# 2개의 user 모두 한 객체에 담을 수 있다.

for user in users:
    print(user.attrib)
    print(user.find("name").text)
# Out:
# {'grade': 'gold'}
# Kim Cheol Soo
# {'grade': 'diamond'}
# Kim Yoo Mee

# %% [markdown]
# #### (4) Document Sample

# %%
str = """<?xml version="1.0"?>
<data>
    <country name="Liechtenstein">
        <rank>1</rank>
        <year>2008</year>
        <gdppc>141100</gdppc>
        <neighbor name="Austria" direction="E"/>
        <neighbor name="Switzerland" direction="W"/>
    </country>
    <country name="Singapore">
        <rank>4</rank>
        <year>2011</year>
        <gdppc>59900</gdppc>
        <neighbor name="Malaysia" direction="N"/>
    </country>
    <country name="Panama">
        <rank>68</rank>
        <year>2011</year>
        <gdppc>13600</gdppc>
        <neighbor name="Costa Rica" direction="W"/>
        <neighbor name="Colombia" direction="E"/>
    </country>
</data>
"""

tree3 = elemTree.fromstring(str)

# %%
# 싱가포르 이웃나라 : 말레이시아
# 파나마에 있는 이웃나라 중 코스타리카의 방향 : W
# 각 나라의 gdppc 조회 : 
# 각 나라의 인접국가 조회

#### 1.
country = tree3.find("./country[@name='Singapore']")
neighbor = country.find('neighbor')
print(neighbor.get("name"))

#### 2. 
country = tree3.find("./country[@name='Panama']")
neighbor = country.find('neighbor[@name="Costa Rica"]')
print(neighbor.get("direction"))

#### 3. 
users = tree3.findall("./country")

for user in users:
    print(user.find("gdppc").text)

#### 4.
users = tree3.findall("./country")

for user in users:
    print(user.find("neighbor").get("name"))
# Out:
# Malaysia
# W
# 141100
# 59900
# 13600
# Austria
# Malaysia
# Costa Rica

# %% [markdown]
# #### (5) 온라인상에서 xml 불러오기

# %%
import requests

health = requests.get("http://www.k-health.com/rss/allArticle.xml")
tree4 = elemTree.fromstring(health.text)
tree4
# Out:
# <Element 'rss' at 0x7f7e18cece50>

# %% [markdown]
# ## JSON(JavaScript Object Notation)

# %%
import json
# dumps() : 데이터 저장
# loads() : 데이터 불러오기

# %%
j1 = {"name" : "홍길동", "birth" : "0101", "age" : 20}
print(type(j1))
# dict

#### 이걸 인터넷으로 보낼 땐 json 형태로 보내야 해.
#### dumps()를 쓰자.

j2 = json.dumps(j1, indent=2) # indent는 들여쓰기 옵션. 키별 구분 확실해 더 편하게 볼 수 있다.
print(type(j2))
print(j2)
# Out:
# <class 'dict'>
# <class 'str'>
# {
#   "name": "\ud64d\uae38\ub3d9",
#   "birth": "0101",
#   "age": 20
# }

# %%
j3 = json.dumps((1, 2, 3))
print(j3)
print(type(j3))
# Out:
# [1, 2, 3]
# <class 'str'>

# %%
j4 = json.loads(j2)
print(j4)
print(type(j4)) # class : 'dict
#### json 파일을 dict 형태로 컨버팅해서 로드해준다.
# Out:
# {'name': '홍길동', 'birth': '0101', 'age': 20}
# <class 'dict'>

# %%
obj = """
{
	"id": "0001",
	"type": "donut",
	"name": "Cake",
	"ppu": 0.55,
	"batters":
		{
			"batter":
				[
					{ "id": "1001", "type": "Regular" },
					{ "id": "1002", "type": "Chocolate" },
					{ "id": "1003", "type": "Blueberry" },
					{ "id": "1004", "type": "Devil's Food" }
				]
		},
	"topping":
		[
			{ "id": "5001", "type": "None" },
			{ "id": "5002", "type": "Glazed" },
			{ "id": "5005", "type": "Sugar" },
			{ "id": "5007", "type": "Powdered Sugar" },
			{ "id": "5006", "type": "Chocolate with Sprinkles" },
			{ "id": "5003", "type": "Chocolate" },
			{ "id": "5004", "type": "Maple" }
		]
}
"""

# %%
result = json.loads(obj)

result['batters']['batter'][0]['id']
# Out:
# '1001'

# %% [markdown]
# ## Beautiful Soup 4

# %% [markdown]
# #### (1) Web에서 Source 가져오기 : 인터넷에서 원하는 정보 가져오기

# %%
# 예외처리를 잘해줘야한다. 오류 발생하더라도 나머지 코드는 잘 진행하기 위해.
# 프로그램을 안전하게 돌릴 수 있는 방법
import urllib.request as req
from urllib.request import urlopen
from urllib.error import HTTPError, URLError

# %%
# 데이터를 가져오는건 쉬워. 중요한건 '내가 원하는 정보를 골라내는 것'이다.
google = urlopen("https://www.google.com")
html = google.read()
html
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="ko"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="BA2oCqCj9yE433GVVYIs9w==">(function(){window.google={kEI:\'TOWJYajeDvnS1sQPqZu-gAY\',kEXPI:\'0,18167,1284369,56873,1709,4349,207,4804,925,1391,383,246,5,1354,4013,1238,1122515,1197772,303190,26305,51224,16114,28684,17572,1326,3533,1361,9290,3030,4744,12835,4020,978,13228,3847,10622,21822,919,5081,1593,1279,2212,530,149,1103,840,2196,4101,3514,606,2023,1777,520,6345,8325,3227,1989,856,7,4773,826,6755,5096,16320,908,2,941,15756,3,346,230,6459,149,12314,1661,4,1252,276,2304,7039,4684,2014,18375,2658,6701,656,30,5615,8013,2305,2132,13406,3380,5818,2539,4097,3135,6,908,3,1166,2375,1,5096,2,1,3,6840,4582,283,912,5992,14660,676,2,1390,1715,2,3035,10987,1931,3909,1680,743,5853,1576,3,7747,539,598,1160,6700,2378
# ...

# %%
#### 정식으로 데이터 크롤링 프로그램 만든다면 예외처리 해야한다.
#### 이렇게!!
#### 에러 발생하면 HTTP Error 입니다. HTTP Error 404: Not Found 이렇게 뜸

try:
    google = urlopen("https://www.google.com/")
except HTTPError as e:
    print("HTTP Error 입니다.", e)
except URLError as e:
    print("URL Error 입니다.", e)

else:
    html = google.read()

# %%
#### 이미지 가져오기
req.urlretrieve("https://www.google.com/images/branding/googlelogo/2x/googlelogo_light_color_272x92dp.png", "data/google.png")
# Out:
# ('data/google.png', <http.client.HTTPMessage at 0x7f7e08a64d30>)

# %%
img = urlopen("https://www.google.com/images/branding/googlelogo/2x/googlelogo_light_color_272x92dp.png")
img_data = img.read()

f = open("data/google.png", "wb")
f.write(img_data)
f.close()

# %%
#### 요청방식
# 프로토콜 : //서버주소:포트번호/폴더 또는 파일명
# 예) https://www.naver.com:80
# 80이 기본. 그래서 우린 이를 생략하고 들어갈 수 있음
# 서버 포트번호를 90으로 바꾸면 90인 것을 아는 사람만 접속할 수 있음
# 가성공간에 폴더와 파일에 접근하고자 하는 경우
# 예) https://www.naver.com/folder/file.py#섹션명

# 서버 접근한 후 값을 전달해야할 경우엔?
# ://서버주소:포트번호/folder/file.py?변수명=값&변수명=값


#https://www.weather.go.kr/weather/lifenindustry/sevice_rss.jsp

# %%
import urllib.parse

api = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"
value = {'stnId' : 109}

params = urllib.parse.urlencode(value)
print(params)

url = api + "?" + params
print(url)

data = urlopen(url).read()
#decode 해주는 이유는 한글이 깨지기 때문.
print(data.decode("utf-8"))
# Out:
# stnId=109
# http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=109
# <?xml version="1.0" encoding="utf-8" ?>
# <rss version="2.0">
# <channel>
# <title>기상청 육상 중기예보</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_02.jsp</link>
# <description>기상청 날씨 웹서비스</description>
# <language>ko</language>
# <generator>기상청</generator>
# <pubDate>2021년 11월 09일 (화)요일 06:00</pubDate>
#  <item>
# <author>기상청</author>
# <category>육상중기예보</category>
# <title>서울,경기도 육상 중기예보 - 2021년 11월 09일 (화)요일 06:00 발표</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_02.jsp</link>
# <guid>http://www.kma.go.kr/weather/forecast/mid-term_02.jsp</guid>
# <description>
# 	<header>
# 		<title>서울,경기도 육상중기예보</title>
# 		<tm>202111090600</tm>
# ...

# %% [markdown]
# #### (2) bs4, BeautifulSoup 사용해서 크롤링하기

# %%
import bs4
from bs4 import BeautifulSoup

# %%
page = open("data/test_first.html").read()
#page

soup =BeautifulSoup(page, "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Very Simple HTML Code by Netsong7
#   </title>
#  </head>
#  <body>
#   <div>
#    <p class="inner-text first-item" id="first">
#     Happy PinkWink.
#     <a href="http://netsong7.synology.me" id="pw-link">
#      PinkWink
#     </a>
#    </p>
#    <p class="inner-text second-item">
#     Happy Data Science.
#     <a href="https://www.python.org" id="py-link">
#      Python
#     </a>
#    </p>
#   </div>
#   <p class="outer-text first-item" id="second">
#    <b>
#     Data Science is funny.
#    </b>
#   </p>
#   <p class="outer-text">
#    <b>
#     All I need is Love.
#    </b>
#   </p>
#  </body>
# </html>

# %%
#### 원하는 위치에 접근하는 방법(순차적 방법)
# 동명의 태그가 여러 개 있을 때, 이 방법이 가장 확실하다.
list(soup.children)
# Out:
# ['html',
#  '\n',
#  <html><head>
#  <title>Very Simple HTML Code by Netsong7</title>
#  </head><body>
#  <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://netsong7.synology.me" id="pw-link">PinkWink</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>
#  </body>
#  </html>]

# %%
html = list(soup.children)[2]
html
# Out:
# <html><head>
# <title>Very Simple HTML Code by Netsong7</title>
# </head><body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://netsong7.synology.me" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>
# </html>

# %%
list(html.children)[1]
# 대부분 중요한 내용은 body에 있음
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://netsong7.synology.me" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %%
body = list(html.children)[1]

# %%
list(body.children)
# Out:
# ['\n',
#  <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://netsong7.synology.me" id="pw-link">PinkWink</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>,
#  '\n',
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>,
#  '\n',
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>,
#  '\n']

# %%
#### 태그명으로 접근하는 방법
#### list[]
soup.body
soup.body.div
soup.body.div.p
# Out:
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://netsong7.synology.me" id="pw-link">PinkWink</a>
# </p>

# %%
#### find, find_all

soup.find('p')

#리스트로 저장되어있는만큼 인덱싱으로 접근 가능
soup.find_all('p')
soup.find_all('p')[3]

#클래스를 이용해서 접근 가능
soup.find_all('p', class_='outer-text')

#id로 접근 가능
soup.find_all('p', id ="second")

#text를 뽑아오자.
a = soup.find_all('p', id="second")[0]
a.text
# Out:
# '\n\n                Data Science is funny.\n            \n'

# %%
#현재 위치
soup.head

#다음 형제인 body로 넘어가고 싶어
soup.head.next_sibling

soup.body.previous_sibling
soup.body.previous_sibling.next_sibling

soup.body.div.parent
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://netsong7.synology.me" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %%
#### 데이터 가져오기

soup.html.get_text()
soup.head.get_text()
soup.title.get_text()
soup.div.get_text()
soup.p.get_text()

#### 모든 p 태그의 글을 가져오지 않는다.
#### 모든 p 태그의 글들을 가져오려면?

for i in soup.find_all("p"):
    print(i.get_text())
# Out:
#                 Happy PinkWink.
#                 PinkWink
#
#
#                 Happy Data Science.
#                 Python
#
#
#
#                 Data Science is funny.
#
#
#
#
#                 All I need is Love.

# %%
# bs4 도큐멘트(한글번역)

https://www.crummy.com/software/BeautifulSoup/bs4/doc.ko/

# %%
#### 속성에 접근하는 방법
#### href 속성에 접근해보자. class처럼 옵션이 있지 않아.

link = soup.find('a')
link
#<a href="http://netsong7.synology.me" id="pw-link">PinkWink</a>

link['href']

for i in soup.find_all('a'):
    print(i['href'])
# Out:
# http://netsong7.synology.me
# https://www.python.org

# %% [markdown]
# #### 스크래핑 연습

# %%
import requests
from urllib.request import urlopen

url = "http://www.pythonscraping.com/pages/warandpeace.html"
page = urlopen(url)
soup = BeautifulSoup(page, "html.parser")

# %%
#### 녹색단어만 골라오기

green = soup.find_all("span", class_ = "green")

for i in green:
    print(i.get_text())
# Out:
# Anna
# Pavlovna Scherer
# Empress Marya
# Fedorovna
# Prince Vasili Kuragin
# Anna Pavlovna
# St. Petersburg
# the prince
# Anna Pavlovna
# Anna Pavlovna
# the prince
# the prince
# the prince
# Prince Vasili
# Anna Pavlovna
# Anna Pavlovna
# the prince
# Wintzingerode
# King of Prussia
# le Vicomte de Mortemart
# Montmorencys
# Rohans
# Abbe Morio
# the Emperor
# the prince
# Prince Vasili
# Dowager Empress Marya Fedorovna
# the baron
# Anna Pavlovna
# the Empress
# the Empress
# Anna Pavlovna's
# Her Majesty
# Baron
# Funke
# The prince
# Anna
# Pavlovna
# the Empress
# The prince
# Anatole
# the prince
# The prince
# Anna
# Pavlovna
# Anna Pavlovna

# %%
green = soup.find_all("span", {"class" : "green"})

for i in green:
    print(i.get_text())
# Out:
# Anna
# Pavlovna Scherer
# Empress Marya
# Fedorovna
# Prince Vasili Kuragin
# Anna Pavlovna
# St. Petersburg
# the prince
# Anna Pavlovna
# Anna Pavlovna
# the prince
# the prince
# the prince
# Prince Vasili
# Anna Pavlovna
# Anna Pavlovna
# the prince
# Wintzingerode
# King of Prussia
# le Vicomte de Mortemart
# Montmorencys
# Rohans
# Abbe Morio
# the Emperor
# the prince
# Prince Vasili
# Dowager Empress Marya Fedorovna
# the baron
# Anna Pavlovna
# the Empress
# the Empress
# Anna Pavlovna's
# Her Majesty
# Baron
# Funke
# The prince
# Anna
# Pavlovna
# the Empress
# The prince
# Anatole
# the prince
# The prince
# Anna
# Pavlovna
# Anna Pavlovna

# %%
green1 = soup.find_all("span", {"class" : "green"})

for i in green1:
    print(i.text)
# Out:
# Anna
# Pavlovna Scherer
# Empress Marya
# Fedorovna
# Prince Vasili Kuragin
# Anna Pavlovna
# St. Petersburg
# the prince
# Anna Pavlovna
# Anna Pavlovna
# the prince
# the prince
# the prince
# Prince Vasili
# Anna Pavlovna
# Anna Pavlovna
# the prince
# Wintzingerode
# King of Prussia
# le Vicomte de Mortemart
# Montmorencys
# Rohans
# Abbe Morio
# the Emperor
# the prince
# Prince Vasili
# Dowager Empress Marya Fedorovna
# the baron
# Anna Pavlovna
# the Empress
# the Empress
# Anna Pavlovna's
# Her Majesty
# Baron
# Funke
# The prince
# Anna
# Pavlovna
# the Empress
# The prince
# Anatole
# the prince
# The prince
# Anna
# Pavlovna
# Anna Pavlovna

# %%
#### CSS에서 스크래핑하는 방법.
# #은 id가 있을 때
# div#text는 span class green을 둘러싸고 있는 부모. 부모에서 접근해야하므로
# 
green2 = soup.select("div#text > span.green")

for i in green2:
    print(i.text)
# Out:
# Anna
# Pavlovna Scherer
# Empress Marya
# Fedorovna
# Prince Vasili Kuragin
# Anna Pavlovna
# St. Petersburg
# the prince
# Anna Pavlovna
# Anna Pavlovna
# the prince
# the prince
# the prince
# Prince Vasili
# Anna Pavlovna
# Anna Pavlovna
# the prince
# the prince
# Prince Vasili
# Dowager Empress Marya Fedorovna
# the baron
# Anna Pavlovna
# the Empress
# the Empress
# Anna Pavlovna's
# Her Majesty
# Baron
# Funke
# The prince
# Anna
# Pavlovna
# the Empress
# The prince
# the prince
# The prince
# Anna
# Pavlovna
# Anna Pavlovna

# %%
#### 제목 추출

# h1, h2, h3, h4, h5, h6
# 보통 h1, h2, h3까지가 제목으로 쓰임


title = soup.find_all(["h1", "h2"])

for i in title:
    print(i.text)
# Out:
# War and Peace
# Chapter 1

# %%
h = soup.find_all(["h" + str(x) for x in range(1, 7)])
for _ in h:
    print(_.get_text())

#숫자를 반복문 돌리는 방법! :)
# Out:
# War and Peace
# Chapter 1

# %%
title1 = soup.select("h1, h2")

for i in title1:
    print(i.text)
# Out:
# War and Peace
# Chapter 1

# %%
# 리스트에 담고 싶다면? 한줄로 끝낼 수 있다.
print([title2.text for title2 in title1])
# Out:
# ['War and Peace', 'Chapter 1']

# %%
r = soup.find_all("span", class_ = "red")
g = soup.find_all("span", class_ = "green")

red = [red_word.text for red_word in r]
green = [green_word.text for green_word in g]

print(red)
print(green)
# Out:
# ["Well, Prince, so Genoa and Lucca are now just family estates of the\nBuonapartes. But I warn you, if you don't tell me that this means war,\nif you still try to defend the infamies and horrors perpetrated by\nthat Antichrist- I really believe he is Antichrist- I will have\nnothing more to do with you and you are no longer my friend, no longer\nmy 'faithful slave,' as you call yourself! But how do you do? I see\nI have frightened you- sit down and tell me all the news.", 'If you have nothing better to do, Count [or Prince], and if the\nprospect of spending an evening with a poor invalid is not too\nterrible, I shall be very charmed to see you tonight between 7 and 10-\nAnnette Scherer.', 'Heavens! what a virulent attack!', "First of all, dear friend, tell me how you are. Set your friend's\nmind at rest,", 'Can one be well while suffering morally? Can one be calm in times\nlike these if one has any feeling?', 'You are\nstaying the whole evening, I hope?', "And the fete at the English
# ...

# %%
url = "http://www.pythonscraping.com/pages/page3.html"
page = urlopen(url)
soup = BeautifulSoup(page, "html.parser")

# %%
#### img 소스도 가져오기
tr = soup.find("table", {"id" : "giftList", }).tr.next_siblings
for t in tr:
    if(type(t) == bs4.element.Tag):
        print(t.get_text(), t.img['src'])
        print(list(t.children)[3].img["src"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/dx/ny9cjsmd1bb3r42zbp694xkh0000gn/T/ipykernel_1396/3598964718.py in <module>
#       4     if(type(t) == bs4.element.Tag):
#       5         print(t.get_text(), t.img['src'])
# ----> 6     print(list(t.children)[3].img["src"])
#
# ~/opt/anaconda3/envs/datastudy/lib/python3.9/site-packages/bs4/element.py in __getattr__(self, attr)
#     733             return self
#     734         else:
# --> 735             raise AttributeError(
#     736                 "'%s' object has no attribute '%s'" % (
#     737                     self.__class__.__name__, attr))
#
# AttributeError: 'NavigableString' object has no attribute 'children'

# %%
#### 가격 중에 $15만 추출

print(soup.find_all("td")[2].text.replace("\n", ""))
print(soup.select('td')[2].text)

print(soup.find("img", src="../img/gifts/img1.jpg").parent.previous_sibling.get_text())
# Out:
# $15.00
#
# $15.00
#
#
# $15.00

# %%
list = soup.find_all("tr", class_='gift')
print(list[0])
print("="*50)
print(list[0].find_all("td"))
print("="*50)
print(list[0].find_all("td")[0])
# Out:
# <tr class="gift" id="gift1"><td>
# Vegetable Basket
# </td><td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# </td><td>
# $15.00
# </td><td>
# <img src="../img/gifts/img1.jpg"/>
# </td></tr>
# ...
# [<td>
# Vegetable Basket
# </td>, <td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# </td>, <td>
# $15.00
# </td>, <td>
# <img src="../img/gifts/img1.jpg"/>
# </td>]
# ...
# <td>
# Vegetable Basket
# </td>

# %%
item = []
explain=[]
price=[]

for i in list:
    item.append(i.find_all("td")[0].text.replace("\n", ""))
    explain.append(i.find_all("td")[1].text.replace("\n", ""))
    price.append(i.find_all("td")[2].text.replace("\n", ""))

table = pd.DataFrame(columns=[item, explain, price])
table = table.T
table
# Out:
# Empty DataFrame
# Columns: []
# Index: [(Vegetable Basket, This vegetable basket is the perfect gift for your health conscious (or overweight) friends!Now with super-colorful bell peppers!, $15.00), (Russian Nesting Dolls, Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! 8 entire dolls per set! Octuple the presents!, $10,000.52), (Fish Painting, If something seems fishy about this painting, it's because it's a fish! Also hand-painted by trained monkeys!, $10,005.00), (Dead Parrot, This is an ex-parrot! Or maybe he's only resting?, $0.50), (Mystery Box, If you love suprises, this mystery box is for you! Do not place on light-colored surfaces. May cause oil staining. Keep your friends guessing!, $1.50)]
