# %% [markdown]
# # 추천시스템
# - 하나의 콘텐츠를 선택했을 때, 선택된 컨텐츠와 연관된 추천 컨텐츠를 제공하는 서비스 시스템
# - 대표적으로 사용하는 데이터
#     1. 사용자가 선택한 컨텐츠
#     2. 사용자가 실제 구매와 연관된 액션을 했는가 여부
#     3. 사용자가 선택한 컨텐츠에 내린 평가 데이터
#     4. 사용자가 스스로 작성한 자신의 취향
#     5. 사용자가 무엇을 클릭했는지...
#
# ## 1. 추천시스템 유형
# - 협업 필터링 vs 콘텐츠 기반 필터링
#     1. 협업 필터링: 최근접이웃 협업 vs 잠재요인 협업
#         + 협업필터링이란, 사용자-아이템 평점 매트릭스와 같은 축적된 사용자 행동 데이터 기반으로 사용자가 아직 평가하지 않은 아이템을 '예측 평가'하는 것
#         + 최근접 이웃 협업, 잠재요인 협업 모두 사용자-평점 매트릭스만으로 사용자에게 추천함
#         + index는 user, columns는 item1, item2 등으로 구성되어야함. pandas.pivot_table() 이용해 변경해야함
#         + 예시. 영화 {범죄도시1: 평점 8.5점, 범죄도시2: 평점 9점, 범죄도시3: 평점 8점} => 범죄도시 4: 평점 8.75로 예측
#         + 최근접이웃 협업: 사용자 기반 vs 아이템 기반
#             * 사용자 기반: 당신과 비슷한 고객들이 다음 상품도 구매했습니다.
#             * 아이템 기반: 이 상품을 선택한 다른 고개들은 다음 상품도 구매했습니다.
#         + 잠재요인 협업: 사용자-아이템 평점 매트리스 속에 숨어 있는 잠재 요인을 추출해 추천하는 기법
#
#     2. 콘텐츠 기반 필터링: 사용자가 특정 아이템을 매우 선호하는 경우, 그 아이템과 비슷한 콘텐츠를 가진 다른 장르 아이템 추천

# %% [markdown]
# ### 잠재요인 행렬 분해 코드
# - SGD를 이용해 행렬분해를 수행
# - 분해하려는 행렬 R
# - P와 Q로 분해 후 다시 P와 Q.T의 내적으로 예측행렬을 만듬

# %%
import numpy as np

# 원본 행렬 R 생성, 분해 행렬 P와 Q 초기화, 잠재 요인 차원 K는 3으로 설정
R = np.array([[4, np.NaN, np.NaN, 2, np.NaN],
              [np.NaN, 5, np.NaN, 3, 1],
              [np.NaN, np.NaN, 3, 4, 4],
              [5, 2, 1, 2, np.NaN]])

num_users, num_items = R.shape
K=3

# P와 Q 행렬의 크기를 지정하고 정규분포를 가진 임의의 값으로 입력
np.random.seed(1)
P = np.random.normal(scale=1./K, size=(num_users, K))
Q = np.random.normal(scale=1./K, size=(num_items, K))

# %%
from sklearn.metrics import mean_squared_error

def get_rmse(R, P, Q, non_zeros):
    error = 0
    # 두 개의 분해된 행렬 P와 Q.T의 내적으로 예측 R 행렬 생성
    full_pred_matrix = np.dot(P, Q.T)

    # 실제 R 행렬에서 Null이 아닌 값의 위치 인덱스 추출해 실제 R 행렬과 예측 행렬의 RMSE 추출
    x_non_zero_index = [non_zero[0] for non_zero in non_zeros]
    y_non_zero_index = [non_zero[1] for non_zero in non_zeros]
    R_non_zeros = R[x_non_zero_index, y_non_zero_index]
    full_pred_matrix_non_zeros = full_pred_matrix[x_non_zero_index, y_non_zero_index]
    mse = mean_squared_error(R_non_zeros, full_pred_matrix_non_zeros)
    rmse = np.sqrt(mse)

    return rmse

# %%
# R > 0인 행 위치, 열 위치, 값을 non_zeros 리스트에 저장
non_zeros = [(i, j , R[i, j]) for i in range(num_users) for j in range(num_items) if R[i, j] > 0]

steps = 1000
lr = 0.01
r_lambda = 0.01

# SGD 기법으로 P와 Q 매트릭스를 계속 업데이트
for step in range(steps):
    for i, j, r in non_zeros:
        # 실제 값과 예측 값의 차이인 오류 값 구하기
        eij = r - np.dot(P[i, :], Q[j, :].T)
        # Regularlization을 반영한 SGD 업데이트 공식 적용
        P[i, :] = P[i, :] + lr*(eij*Q[j, :] - r_lambda*P[i, :])
        Q[j, :] = Q[j, :] + lr*(eij*P[i, :] - r_lambda*Q[j, :])
        rmse = get_rmse(R, P, Q, non_zeros)
        if step % 50 == 0:
            print(f"[행렬분해 중] iteration step: {step}, rmse: {rmse}")
# Out:
# [행렬분해 중] iteration step: 0, rmse: 3.261355059488935
# [행렬분해 중] iteration step: 0, rmse: 3.26040057174686
# [행렬분해 중] iteration step: 0, rmse: 3.253984404542389
# [행렬분해 중] iteration step: 0, rmse: 3.2521583839863624
# [행렬분해 중] iteration step: 0, rmse: 3.252335303789125
# [행렬분해 중] iteration step: 0, rmse: 3.251072196430487
# [행렬분해 중] iteration step: 0, rmse: 3.2492449982564864
# [행렬분해 중] iteration step: 0, rmse: 3.247416477570409
# [행렬분해 중] iteration step: 0, rmse: 3.241926055455223
# [행렬분해 중] iteration step: 0, rmse: 3.2400454107613084
# [행렬분해 중] iteration step: 0, rmse: 3.240166740749792
# [행렬분해 중] iteration step: 0, rmse: 3.2388050277987723
# [행렬분해 중] iteration step: 50, rmse: 0.5003190892212749
# [행렬분해 중] iteration step: 50, rmse: 0.5001616291326989
# [행렬분해 중] iteration step: 50, rmse: 0.4989960120257809
# [행렬분해 중] iteration step: 50, rmse: 0.498848345014583
# [행렬분해 중] iteration step: 50, rmse: 0.4989518925663175
# [행렬분해 중] iteration step: 50, rmse: 0.4983323683009099
# [행렬분해 중] iteration step: 50, rmse: 0.4984148489378701
# [행렬분해 중] iteration step: 50, rmse: 0.49792599580240876
# [행렬분해 중] iteration step: 50, rmse: 0.4900605568692785
# [행렬분해 중] iteration step: 50, rmse: 0.4890370238665434
# [행렬분해 중] iteration step: 50, rmse: 0.48869176023997846
# [행렬분해 중] iteration step: 50, rmse: 0.4876723101369647
# [행렬분해 중] iteration step: 100, rmse: 0.15911521988578556
# [행렬분해 중] iteration step: 100, rmse: 0.15880916178010931
# [행렬분해 중] iteration step: 100, rmse: 0.15874092217089011
# [행렬분해 중] iteration step: 100, rmse: 0.15828569528425077
# [행렬분해 중] iteration step: 100, rmse: 0.15830809482168753
# [행렬분해 중] iteration step: 100, rmse: 0.15828832993767397
# [행렬분해 중] iteration step: 100, rmse: 0.15787486893092847
# [행렬분해 중] iteration step: 100, rmse: 0.15792073606567075
# [행렬분해 중] iteration step: 100, rmse: 0.15725245215457076
# [행렬분해 중] iteration step: 100, rmse: 0.15710664164665206
# [행렬분해 중] iteration step: 100, rmse: 0.1569025214419
# [행렬분해 중] iteration step: 100, rmse: 0.15643403848192458
# [행렬분해 중] iteration step: 150, rmse: 0.07546004875264456
# [행렬분해 중] iteration step: 150, rmse: 0.07544589133447119
# [행렬분해 중] iteration step: 150, rmse: 0.07543234329653034
# [행렬분해 중] iteration step: 150, rmse: 0.07514800672233916
# [행렬분해 중] iteration step: 150, rmse: 0.07518867696418184
# [행렬분해 중] iteration step: 150, rmse: 0.07522889509938421
# [행렬분해 중] iteration step: 150, rmse: 0.0748931886446927
# [행렬분해 중] iteration step: 150, rmse: 0.07493400425933266
# [행렬분해 중] iteration step: 150, rmse: 0.07462695506527875
# [행렬분해 중] iteration step: 150, rmse: 0.07464332131959682
# [행렬분해 중] iteration step: 150, rmse: 0.07464441641563421
# [행렬분해 중] iteration step: 150, rmse: 0.07455141311978064
# [행렬분해 중] iteration step: 200, rmse: 0.0436101657943908
# [행렬분해 중] iteration step: 200, rmse: 0.043709130689530334
# [행렬분해 중] iteration step: 200, rmse: 0.04369072102767999
# [행렬분해 중] iteration step: 200, rmse: 0.04347554983227157
# [행렬분해 중] iteration step: 200, rmse: 0.04353130925373599
# [행렬분해 중] iteration step: 200, rmse: 0.04359240037575308
# [행렬분해 중] iteration step: 200, rmse: 0.04329647906053857
# [행렬분해 중] iteration step: 200, rmse: 0.04332057192123641
# [행렬분해 중] iteration step: 200, rmse: 0.043104482945025314
# [행렬분해 중] iteration step: 200, rmse: 0.043135502866585615
# [행렬분해 중] iteration step: 200, rmse: 0.04313786864806276
# [행렬분해 중] iteration step: 200, rmse: 0.043252267985793146
# [행렬분해 중] iteration step: 250, rmse: 0.0293951831856098
# [행렬분해 중] iteration step: 250, rmse: 0.029544029484371757
# [행렬분해 중] iteration step: 250, rmse: 0.029501874367581973
# [행렬분해 중] iteration step: 250, rmse: 0.029329609713572624
# [행렬분해 중] iteration step: 250, rmse: 0.029402118073276706
# [행렬분해 중] iteration step: 250, rmse: 0.029467205684175147
# [행렬분해 중] iteration step: 250, rmse: 0.029189294191791382
# [행렬분해 중] iteration step: 250, rmse: 0.029198757426747685
# [행렬분해 중] iteration step: 250, rmse: 0.02899574226000236
# [행렬분해 중] iteration step: 250, rmse: 0.029044154450545513
# [행렬분해 중] iteration step: 250, rmse: 0.029049587101179625
# [행렬분해 중] iteration step: 250, rmse: 0.029248328780879226
# [행렬분해 중] iteration step: 300, rmse: 0.02267871523374936
# [행렬분해 중] iteration step: 300, rmse: 0.022844873864300484
# [행렬분해 중] iteration step: 300, rmse: 0.02277356665032507
# [행렬분해 중] iteration step: 300, rmse: 0.022632345073225105
# [행렬분해 중] iteration step: 300, rmse: 0.022720062551531153
# [행렬분해 중] iteration step: 300, rmse: 0.022778917442558343
# [행렬분해 중] iteration step: 300, rmse: 0.02251624306238127
# [행렬분해 중] iteration step: 300, rmse: 0.022515508246519742
# [행렬분해 중] iteration step: 300, rmse: 0.02229491665298547
# [행렬분해 중] iteration step: 300, rmse: 0.022367287171783122
# [행렬분해 중] iteration step: 300, rmse: 0.02239230348065316
# [행렬분해 중] iteration step: 300, rmse: 0.022621116143829507
# [행렬분해 중] iteration step: 350, rmse: 0.019516973680183958
# [행렬분해 중] iteration step: 350, rmse: 0.019681605297160662
# [행렬분해 중] iteration step: 350, rmse: 0.019585635379668606
# [행렬분해 중] iteration step: 350, rmse: 0.019467165455250065
# [행렬분해 중] iteration step: 350, rmse: 0.019565686789792668
# [행렬분해 중] iteration step: 350, rmse: 0.019614020075870636
# [행렬분해 중] iteration step: 350, rmse: 0.019368393329296515
# [행렬분해 중] iteration step: 350, rmse: 0.019361014872335155
# [행렬분해 중] iteration step: 350, rmse: 0.019116038405167703
# [행렬분해 중] iteration step: 350, rmse: 0.019209815479975148
# [행렬분해 중] iteration step: 350, rmse: 0.019255623979392383
# [행렬분해 중] iteration step: 350, rmse: 0.019493636196525232
# [행렬분해 중] iteration step: 400, rmse: 0.01803666559195474
# [행렬분해 중] iteration step: 400, rmse: 0.018191331063344373
# [행렬분해 중] iteration step: 400, rmse: 0.018078504374883713
# [행렬분해 중] iteration step: 400, rmse: 0.01797554592952722
# [행렬분해 중] iteration step: 400, rmse: 0.018080509676855996
# [행렬분해 중] iteration step: 400, rmse: 0.018118882879536797
# [행렬분해 중] iteration step: 400, rmse: 0.017889686482489495
# [행렬분해 중] iteration step: 400, rmse: 0.017878066671070485
# [행렬분해 중] iteration step: 400, rmse: 0.017612244339685706
# [행렬분해 중] iteration step: 400, rmse: 0.01772096734904676
# [행렬분해 중] iteration step: 400, rmse: 0.017781796456597727
# [행렬분해 중] iteration step: 400, rmse: 0.018022719092132773
# [행렬분해 중] iteration step: 450, rmse: 0.017334045429542207
# [행렬분해 중] iteration step: 450, rmse: 0.017476834937591626
# [행렬분해 중] iteration step: 450, rmse: 0.017353619075108358
# [행렬분해 중] iteration step: 450, rmse: 0.017260553985290757
# [행렬분해 중] iteration step: 450, rmse: 0.017369093850106612
# [행렬분해 중] iteration step: 450, rmse: 0.017399933857257795
# [행렬분해 중] iteration step: 450, rmse: 0.0171843175786375
# [행렬분해 중] iteration step: 450, rmse: 0.0171699064962513
# [행렬분해 중] iteration step: 450, rmse: 0.016888615795792955
# [행렬분해 중] iteration step: 450, rmse: 0.01700663815408313
# [행렬분해 중] iteration step: 450, rmse: 0.017076792508661655
# [행렬분해 중] iteration step: 450, rmse: 0.01731968595344283
# [행렬분해 중] iteration step: 500, rmse: 0.01699160924805319
# [행렬분해 중] iteration step: 500, rmse: 0.0171234089157865
# [행렬분해 중] iteration step: 500, rmse: 0.01699398405641072
# [행렬분해 중] iteration step: 500, rmse: 0.016907070492030378
# [행렬분해 중] iteration step: 500, rmse: 0.017017605772217764
# [행렬분해 중] iteration step: 500, rmse: 0.01704327755670073
# [행렬분해 중] iteration step: 500, rmse: 0.016838031459003783
# [행렬분해 중] iteration step: 500, rmse: 0.016821674312725587
# [행렬분해 중] iteration step: 500, rmse: 0.01652928126442942
# [행렬분해 중] iteration step: 500, rmse: 0.016652888795198606
# [행렬분해 중] iteration step: 500, rmse: 0.016728541275491084
# [행렬분해 중] iteration step: 500, rmse: 0.016973657887570985
# [행렬분해 중] iteration step: 550, rmse: 0.016818969716266428
# [행렬분해 중] iteration step: 550, rmse: 0.01694144559744487
# [행렬분해 중] iteration step: 550, rmse: 0.016808259298884326
# [행렬분해 중] iteration step: 550, rmse: 0.016725234339747642
# [행렬분해 중] iteration step: 550, rmse: 0.016836938491435156
# [행렬분해 중] iteration step: 550, rmse: 0.016859187050621244
# [행렬분해 중] iteration step: 550, rmse: 0.016661644526141703
# [행렬분해 중] iteration step: 550, rmse: 0.016643851020065135
# [행렬분해 중] iteration step: 550, rmse: 0.016343446075494296
# [행렬분해 중] iteration step: 550, rmse: 0.016470440821826447
# [행렬분해 중] iteration step: 550, rmse: 0.016549323314269518
# [행렬분해 중] iteration step: 550, rmse: 0.01679680459589558
# [행렬분해 중] iteration step: 600, rmse: 0.016727439717439153
# [행렬분해 중] iteration step: 600, rmse: 0.016842259158977278
# [행렬분해 중] iteration step: 600, rmse: 0.01670668792446753
# [행렬분해 중] iteration step: 600, rmse: 0.016626255644609494
# [행렬분해 중] iteration step: 600, rmse: 0.016738696939262863
# [행렬분해 중] iteration step: 600, rmse: 0.01675868241598574
# [행렬분해 중] iteration step: 600, rmse: 0.01656685720005292
# [행렬분해 중] iteration step: 600, rmse: 0.016547954461110775
# [행렬분해 중] iteration step: 600, rmse: 0.01624166876076104
# [행렬분해 중] iteration step: 600, rmse: 0.01637080005613797
# [행렬분해 중] iteration step: 600, rmse: 0.0164516272092571
# [행렬분해 중] iteration step: 600, rmse: 0.016701322901884634
# [행렬분해 중] iteration step: 650, rmse: 0.016674291334806118
# [행렬분해 중] iteration step: 650, rmse: 0.016782895588884888
# [행렬분해 중] iteration step: 650, rmse: 0.01664569809164759
# [행렬분해 중] iteration step: 650, rmse: 0.01656714079916211
# [행렬분해 중] iteration step: 650, rmse: 0.016680091021598505
# [행렬분해 중] iteration step: 650, rmse: 0.016698554271430695
# [행렬분해 중] iteration step: 650, rmse: 0.01651101773242772
# [행렬분해 중] iteration step: 650, rmse: 0.016491228766905206
# [행렬분해 중] iteration step: 650, rmse: 0.016180544197961624
# [행렬분해 중] iteration step: 650, rmse: 0.01631111150707523
# [행렬분해 중] iteration step: 650, rmse: 0.01639316772050073
# [행렬분해 중] iteration step: 650, rmse: 0.016644736912476574
# [행렬분해 중] iteration step: 700, rmse: 0.016638362442608513
# [행렬분해 중] iteration step: 700, rmse: 0.0167419367433236
# [행렬분해 중] iteration step: 700, rmse: 0.016603524189001635
# [행렬분해 중] iteration step: 700, rmse: 0.016526454393300506
# [행렬분해 중] iteration step: 700, rmse: 0.016639792083379536
# [행렬분해 중] iteration step: 700, rmse: 0.016657201345297357
# [행렬분해 중] iteration step: 700, rmse: 0.01647292838164141
# [행렬분해 중] iteration step: 700, rmse: 0.01645241257047359
# [행렬분해 중] iteration step: 700, rmse: 0.016138379086448086
# [행렬분해 중] iteration step: 700, rmse: 0.016269993747904974
# [행렬분해 중] iteration step: 700, rmse: 0.01635288508504548
# [행렬분해 중] iteration step: 700, rmse: 0.016605910068210012
# [행렬분해 중] iteration step: 750, rmse: 0.01660906046895513
# [행렬분해 중] iteration step: 750, rmse: 0.01670856296909822
# [행렬분해 중] iteration step: 750, rmse: 0.016569153528341703
# [행렬분해 중] iteration step: 750, rmse: 0.016493367054249884
# [행렬분해 중] iteration step: 750, rmse: 0.01660702796687089
# [행렬분해 중] iteration step: 750, rmse: 0.016623681027525393
# [행렬분해 중] iteration step: 750, rmse: 0.01644192727172457
# [행렬분해 중] iteration step: 750, rmse: 0.016420802465343706
# [행렬분해 중] iteration step: 750, rmse: 0.016104179990850825
# [행렬분해 중] iteration step: 750, rmse: 0.016236628551952983
# [행렬분해 중] iteration step: 750, rmse: 0.01632014100929194
# [행렬분해 중] iteration step: 750, rmse: 0.01657420047570488
# [행렬분해 중] iteration step: 800, rmse: 0.016581161561119988
# [행렬분해 중] iteration step: 800, rmse: 0.016677363428437137
# [행렬분해 중] iteration step: 800, rmse: 0.016537069269613805
# [행렬분해 중] iteration step: 800, rmse: 0.01646246137777885
# [행렬분해 중] iteration step: 800, rmse: 0.016576412350487686
# [행렬분해 중] iteration step: 800, rmse: 0.016592501800249713
# [행렬분해 중] iteration step: 800, rmse: 0.016412717409428523
# [행렬분해 중] iteration step: 800, rmse: 0.016391072859801684
# [행렬분해 중] iteration step: 800, rmse: 0.016072423077368784
# [행렬분해 중] iteration step: 800, rmse: 0.016205589842522038
# [행렬분해 중] iteration step: 800, rmse: 0.016289609430091508
# [행렬분해 중] iteration step: 800, rmse: 0.01654431582921612
# [행렬분해 중] iteration step: 850, rmse: 0.016552228984315465
# [행렬분해 중] iteration step: 850, rmse: 0.016645751215475714
# [행렬분해 중] iteration step: 850, rmse: 0.016504627328190483
# [행렬분해 중] iteration step: 850, rmse: 0.01643114580174884
# [행렬분해 중] iteration step: 850, rmse: 0.016545370571042384
# [행렬분해 중] iteration step: 850, rmse: 0.016561024020104998
# [행렬분해 중] iteration step: 850, rmse: 0.016382795627019667
# [행렬분해 중] iteration step: 850, rmse: 0.01636070007608577
# [행렬분해 중] iteration step: 850, rmse: 0.016040446344395495
# [행렬분해 중] iteration step: 850, rmse: 0.016174269580681248
# [행렬분해 중] iteration step: 850, rmse: 0.01625873735464131
# [행렬분해 중] iteration step: 850, rmse: 0.016513751774735037
# [행렬분해 중] iteration step: 900, rmse: 0.01652128043377805
# [행렬분해 중] iteration step: 900, rmse: 0.016612624200841565
# [행렬분해 중] iteration step: 900, rmse: 0.016470695682262133
# [행렬분해 중] iteration step: 900, rmse: 0.016398314989165507
# [행렬분해 중] iteration step: 900, rmse: 0.01651280633307365
# [행렬분해 중] iteration step: 900, rmse: 0.016528110873501898
# [행렬분해 중] iteration step: 900, rmse: 0.016351122754892623
# [행렬분해 중] iteration step: 900, rmse: 0.01632862978384231
# [행렬분해 중] iteration step: 900, rmse: 0.016007096878603345
# [행렬분해 중] iteration step: 900, rmse: 0.0161415440715142
# [행렬분해 중] iteration step: 900, rmse: 0.01622643084399404
# [행렬분해 중] iteration step: 900, rmse: 0.01648146573819507
# [행렬분해 중] iteration step: 950, rmse: 0.016488081335748327
# [행렬분해 중] iteration step: 950, rmse: 0.016577652134974738
# [행렬분해 중] iteration step: 950, rmse: 0.016434929334981776
# [행렬분해 중] iteration step: 950, rmse: 0.016363636620406127
# [행렬분해 중] iteration step: 950, rmse: 0.016478391959548654
# [행렬분해 중] iteration step: 950, rmse: 0.01649340903060661
# [행렬분해 중] iteration step: 950, rmse: 0.016317416842511017
# [행렬분해 중] iteration step: 950, rmse: 0.01629456857175322
# [행렬분해 중] iteration step: 950, rmse: 0.015972009545965202
# [행렬분해 중] iteration step: 950, rmse: 0.01610706345879575
# [행렬분해 중] iteration step: 950, rmse: 0.016192355609214667
# [행렬분해 중] iteration step: 950, rmse: 0.01644717168347911

# %%
# 분해된 P와 Q 함수를 P*Q.T로 예측행렬 만들기
pred_matrix = np.dot(P,Q.T)
print('예측행렬:\n', np.round(pred_matrix, 3))
# Out:
# 예측행렬:
#  [[3.991 0.897 1.306 2.002 1.663]
#  [6.696 4.978 0.979 2.981 1.003]
#  [6.677 0.391 2.987 3.977 3.986]
#  [4.968 2.005 1.006 2.017 1.14 ]]
